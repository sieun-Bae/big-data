# %% [markdown]
# ## Hadoop Streaming assignment 3: Name Count

# %% [markdown]
# Make WordCount program for all the names in the dataset. Name is a word with the following properties:
#
# The first character is not a digit (other characters can be digits).
# The first character is uppercase, all the other characters that are letters are lowercase.
# There are less than 0.5% occurrences of this word, when this word regardless to its case appears in the dataset and the condition (2) is not met.
# Order by quantity, most popular first, output format:
#
# <pre><code>
# name < tab > count
# </code></pre>
# The result is the 5th line in the output.
#
# The result on the sample dataset:
# <pre><code>
# french 5742
# </code></pre>

# %%
# %%writefile mapper1.py

import sys
import re
for line in sys.stdin:
    article_id, text = line.strip().split('\t',1)
    try:
        words = re.split('\W*\s+\W*', text.strip())
        for word in words:
            cond1 = word[0].isalpha()
            cond2 = word[0].isupper() and word[1:].islower()
            
            if cond1:
                print("{}\t{:d}\t{:d}".format(word.lower(), 1, int(cond2)))
    except Exception as e:
        continue
# Out:
# Writing mapper1.py

# %%
# %%writefile reducer1.py

import sys

current_key = None
word_total = 0
name_total = 0

for line in sys.stdin:
    try:
        key, word_count, name_count = line.strip().split('\t',2)
        word_count = int(word_count)
        name_count = int(name_count)
        if current_key != key:
            if current_key:
                print("{}\t{:d}\t{:d}".format(current_key, name_total, word_total))
                
            current_key = key
            word_total = 0
            name_total = 0
        
        word_total += word_count
        name_total += name_count
    except Exception as e:
        print(e)
        continue 
if current_key:
    print("{}\t{:d}\t{:d}".format(current_key, name_total, word_total))
# Out:
# Writing reducer1.py

# %%
# %%writefile mapper2.py

import sys

current_key = None
word_total = 0
name_total = 0

for line in sys.stdin:
    try:
        key, name_count, word_count = line.strip().split('\t', 2)
        word_count = int(word_count)
        name_count = int(name_count)
        
        if current_key != key:
            if current_key:
                print("{}\t{}\t{}".format(name_total, word_total, current_key))
                
            current_key = key
            word_total = 0
            name_total = 0
        
        word_total += word_count
        name_total += name_count
        
    except ValueError as e:
        print(e)
        continue    

if current_key:
    print("{}\t{}\t{}".format(name_total, word_total, current_key))
# Out:
# Writing mapper2.py

# %%
# %%writefile reducer2.py

import sys

total_count = 0
total_caps = 0
current_word = None

for line in sys.stdin:
    try:
        caps_count, count, key = line.strip().split('\t', 2)
        count = int(count)
        caps_count = int(caps_count)
        
        if key != current_word:
            
            if current_word and float(total_caps) / float(total_count) >= 0.995: 
                print("{}\t{:d}".format(current_word, total_caps))
            
            total_count = 0
            total_caps = 0
            current_word = key


        total_caps += caps_count
        total_count += count

    except Exception as e:
        print e
        continue
        
if current_word and float(total_caps) / float(total_count) >= 0.995: 
    print("{}\t{:d}".format(current_word, total_caps))
# Out:
# Writing reducer2.py

# %%
# %%bash
#
# OUT_DIR_1="assignment3_1_"$(date +"%s%6N")
# OUT_DIR_2="assignment3_2_"$(date +"%s%6N")
# NUM_REDUCERS=4
#
# hdfs dfs -rm -r -skipTrash ${OUT_DIR_1}* > /dev/null
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -files mapper1.py,reducer1.py \
#     -mapper 'python2 mapper1.py' \
#     -reducer 'python2 reducer1.py' \
#     -numReduceTasks ${NUM_REDUCERS} \
#     -input /data/wiki/en_articles_part \
#     -output ${OUT_DIR_1} > /dev/null
#
# hdfs dfs -rm -r -skipTrash ${OUT_DIR_2}* > /dev/null
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapreduce.job.output.key.comparator.class=org.apache.hadoop.mapreduce.lib.partition.KeyFieldBasedComparator \
#     -D mapreduce.partition.keycomparator.options="-k1,3nr" \
#     -files mapper2.py,reducer2.py \
#     -mapper 'python2 mapper2.py' \
#     -reducer 'python2 reducer2.py' \
#     -numReduceTasks 1 \
#     -input ${OUT_DIR_1} \
#     -output ${OUT_DIR_2} > /dev/null
#
# hdfs dfs -cat ${OUT_DIR_2}/part-00000 | sed -n "5p;8q"
# Out:
# french	5740
# rm: `assignment3_1_1615982252928508*': No such file or directory
# 21/03/17 11:57:35 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 21/03/17 11:57:35 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 21/03/17 11:57:35 INFO mapred.FileInputFormat: Total input files to process : 1
# 21/03/17 11:57:35 INFO mapreduce.JobSubmitter: number of splits:2
# 21/03/17 11:57:35 INFO Configuration.deprecation: yarn.resourcemanager.system-metrics-publisher.enabled is deprecated. Instead, use yarn.system-metrics-publisher.enabled
# 21/03/17 11:57:36 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1615980409049_0007
# 21/03/17 11:57:36 INFO conf.Configuration: resource-types.xml not found
# 21/03/17 11:57:36 INFO resource.ResourceUtils: Unable to find 'resource-types.xml'.
# 21/03/17 11:57:36 INFO resource.ResourceUtils: Adding resource type - name = memory-mb, units = Mi, type = COUNTABLE
# 21/03/17 11:57:36 INFO resource.ResourceUtils: Adding resource type - name = vcores, units = , type = COUNTABLE
# 21/03/17 11:57:36 INFO impl.YarnClientImpl: Submitted application application_1615980409049_0007
# 21/03/17 11:57:36 INFO mapreduce.Job: The url to track the job: http://172.17.0.70:8088/proxy/application_1615980409049_0007/
# 21/03/17 11:57:36 INFO mapreduce.Job: Running job: job_1615980409049_0007
# 21/03/17 11:57:41 INFO mapreduce.Job: Job job_1615980409049_0007 running in uber mode : false
# 21/03/17 11:57:41 INFO mapreduce.Job:  map 0% reduce 0%
# 21/03/17 11:57:58 INFO mapreduce.Job:  map 50% reduce 0%
# 21/03/17 11:58:04 INFO mapreduce.Job:  map 74% reduce 0%
# 21/03/17 11:58:05 INFO mapreduce.Job:  map 86% reduce 0%
# 21/03/17 11:58:06 INFO mapreduce.Job:  map 100% reduce 0%
# 21/03/17 11:58:22 INFO mapreduce.Job:  map 100% reduce 20%
# 21/03/17 11:58:24 INFO mapreduce.Job:  map 100% reduce 45%
# 21/03/17 11:58:26 INFO mapreduce.Job:  map 100% reduce 70%
# 21/03/17 11:58:27 INFO mapreduce.Job:  map 100% reduce 95%
# 21/03/17 11:58:28 INFO mapreduce.Job:  map 100% reduce 100%
# 21/03/17 11:58:29 INFO mapreduce.Job: Job job_1615980409049_0007 completed successfully
# 21/03/17 11:58:29 INFO mapreduce.Job: Counters: 50
# 	File System Counters
# 		FILE: Number of bytes read=280966143
# 		FILE: Number of bytes written=422666144
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=76874501
# 		HDFS: Number of bytes written=5484188
# 		HDFS: Number of read operations=18
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=8
# 	Job Counters
# 		Killed reduce tasks=1
# 		Launched map tasks=2
# 		Launched reduce tasks=5
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=44823
# 		Total time spent by all reduces in occupied slots (ms)=66150
# 		Total time spent by all map tasks (ms)=44823
# 		Total time spent by all reduce tasks (ms)=66150
# 		Total vcore-milliseconds taken by all map tasks=44823
# 		Total vcore-milliseconds taken by all reduce tasks=66150
# 		Total megabyte-milliseconds taken by all map tasks=45898752
# 		Total megabyte-milliseconds taken by all reduce tasks=67737600
# 	Map-Reduce Framework
# 		Map input records=4100
# 		Map output records=11472777
# 		Map output bytes=117525361
# 		Map output materialized bytes=140470972
# 		Input split bytes=228
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=369512
# 		Reduce shuffle bytes=140470972
# 		Reduce input records=11472777
# 		Reduce output records=369512
# 		Spilled Records=34418331
# 		Shuffled Maps =8
# 		Failed Shuffles=0
# 		Merged Map outputs=8
# 		GC time elapsed (ms)=2022
# 		CPU time spent (ms)=49860
# 		Physical memory (bytes) snapshot=1417981952
# 		Virtual memory (bytes) snapshot=11554902016
# 		Total committed heap usage (bytes)=919076864
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=76874273
# 	File Output Format Counters
# 		Bytes Written=5484188
# 21/03/17 11:58:29 INFO streaming.StreamJob: Output directory: assignment3_1_1615982252928508
# rm: `assignment3_2_1615982252929377*': No such file or directory
# 21/03/17 11:58:32 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 21/03/17 11:58:32 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 21/03/17 11:58:32 INFO mapred.FileInputFormat: Total input files to process : 4
# 21/03/17 11:58:32 INFO mapreduce.JobSubmitter: number of splits:4
# 21/03/17 11:58:33 INFO Configuration.deprecation: yarn.resourcemanager.system-metrics-publisher.enabled is deprecated. Instead, use yarn.system-metrics-publisher.enabled
# 21/03/17 11:58:33 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1615980409049_0008
# 21/03/17 11:58:33 INFO conf.Configuration: resource-types.xml not found
# 21/03/17 11:58:33 INFO resource.ResourceUtils: Unable to find 'resource-types.xml'.
# 21/03/17 11:58:33 INFO resource.ResourceUtils: Adding resource type - name = memory-mb, units = Mi, type = COUNTABLE
# 21/03/17 11:58:33 INFO resource.ResourceUtils: Adding resource type - name = vcores, units = , type = COUNTABLE
# 21/03/17 11:58:33 INFO impl.YarnClientImpl: Submitted application application_1615980409049_0008
# 21/03/17 11:58:33 INFO mapreduce.Job: The url to track the job: http://172.17.0.70:8088/proxy/application_1615980409049_0008/
# 21/03/17 11:58:33 INFO mapreduce.Job: Running job: job_1615980409049_0008
# 21/03/17 11:58:40 INFO mapreduce.Job: Job job_1615980409049_0008 running in uber mode : false
# 21/03/17 11:58:40 INFO mapreduce.Job:  map 0% reduce 0%
# 21/03/17 11:58:50 INFO mapreduce.Job:  map 100% reduce 0%
# 21/03/17 11:58:55 INFO mapreduce.Job:  map 100% reduce 100%
# 21/03/17 11:58:55 INFO mapreduce.Job: Job job_1615980409049_0008 completed successfully
# 21/03/17 11:58:55 INFO mapreduce.Job: Counters: 49
# 	File System Counters
# 		FILE: Number of bytes read=6223239
# 		FILE: Number of bytes written=13492991
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=5484696
# 		HDFS: Number of bytes written=1484298
# 		HDFS: Number of read operations=15
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=4
# 		Launched reduce tasks=1
# 		Data-local map tasks=4
# 		Total time spent by all maps in occupied slots (ms)=32215
# 		Total time spent by all reduces in occupied slots (ms)=2757
# 		Total time spent by all map tasks (ms)=32215
# 		Total time spent by all reduce tasks (ms)=2757
# 		Total vcore-milliseconds taken by all map tasks=32215
# 		Total vcore-milliseconds taken by all reduce tasks=2757
# 		Total megabyte-milliseconds taken by all map tasks=32988160
# 		Total megabyte-milliseconds taken by all reduce tasks=2823168
# 	Map-Reduce Framework
# 		Map input records=369512
# 		Map output records=369512
# 		Map output bytes=5484198
# 		Map output materialized bytes=6223257
# 		Input split bytes=508
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=935
# 		Reduce shuffle bytes=6223257
# 		Reduce input records=369512
# 		Reduce output records=133518
# 		Spilled Records=739024
# 		Shuffled Maps =4
# 		Failed Shuffles=0
# 		Merged Map outputs=4
# 		GC time elapsed (ms)=1122
# 		CPU time spent (ms)=5530
# 		Physical memory (bytes) snapshot=1325850624
# 		Virtual memory (bytes) snapshot=9614467072
# 		Total committed heap usage (bytes)=901775360
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=5484188
# 	File Output Format Counters
# 		Bytes Written=1484298
# 21/03/17 11:58:55 INFO streaming.StreamJob: Output directory: assignment3_2_1615982252929377
# cat: Unable to write to output stream.
